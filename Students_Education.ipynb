# %%
import pandas as pd
import plotly.express as px

# Load the dataset
df = pd.read_csv('Studentdata.csv')

# Create a box plot
fig = px.box(df, x='Grade', y='Test_Score', title='Box Plot of Test Scores by Grade')
fig.show()
# Create a scatter plot
# Create a scatter plot with names as labels
fig = px.scatter(df, x='Attendance', y='Test_Score', color='Grade',
                 text='Name',  # Add 'Name' as labels
                 title='Scatter Plot of Test Scores vs. Attendance with Student Names',
                 labels={'Attendance': 'Attendance (%)', 'Test_Score': 'Test Score'})
fig.update_traces(textposition='top center')  # Adjust the label position
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ca0712f4-8ee9-4255-aabd-19e21e383629" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca0712f4-8ee9-4255-aabd-19e21e383629")) {                    Plotly.newPlot(                        "ca0712f4-8ee9-4255-aabd-19e21e383629",                        [{"alignmentgroup":"True","hovertemplate":"Grade=%{x}\u003cbr\u003eTest_Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["D","B","C","A","F","B","C","A","D","A","A","B","C","D","F","A","A","B","C","D","F","E","B","B","B"],"x0":" ","xaxis":"x","y":[70,89,73,94,40,86,78,92,70,95,96,82,77,66,31,99,99,88,77,66,19,55,87,87,82],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="57c3bc7f-8f66-49c8-a4f0-0793d5a9e0c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57c3bc7f-8f66-49c8-a4f0-0793d5a9e0c9")) {                    Plotly.newPlot(                        "57c3bc7f-8f66-49c8-a4f0-0793d5a9e0c9",                        [{"hovertemplate":"Grade=D\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"D","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"D","orientation":"v","showlegend":true,"text":["jessy","William","Lisa","Raj"],"x":[90,80,60,97],"xaxis":"x","y":[70,70,66,66],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Grade=B\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"B","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers+text","name":"B","orientation":"v","showlegend":true,"text":["saran","Laura","Rose","Karthick","Adam","Mohan","Dharanie"],"x":[95,92,90,79,99,100,80],"xaxis":"x","y":[89,86,82,88,87,87,82],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Grade=C\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers+text","name":"C","orientation":"v","showlegend":true,"text":["Michael","Daniel","Leo","Mano"],"x":[85,88,70,65],"xaxis":"x","y":[73,78,77,77],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Grade=A\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers+text","name":"A","orientation":"v","showlegend":true,"text":["Edward","Olivia","Emma","Jack","ovia","karan"],"x":[100,99,97,100,55,84],"xaxis":"x","y":[94,92,95,96,99,99],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Grade=F\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers+text","name":"F","orientation":"v","showlegend":true,"text":["john","Mona","Krish"],"x":[70,75,64],"xaxis":"x","y":[40,31,19],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Grade=E\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"E","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers+text","name":"E","orientation":"v","showlegend":true,"text":["Sam"],"x":[98],"xaxis":"x","y":[55],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953" ...
